# %%
from PIL import Image
from pytesseract import pytesseract
import os

# %%
p_t_t=r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
p_t_i=r'../DS/Task1/'

# %%
pytesseract.tessesract_cmd = p_t_t

#Get the file names in the directory
for root, dirs, file_names in os.walk(p_t_i):
    #Iterate over each file name in the folder
    for file_name in file_names:
        #Open image with PIL
        img = Image.open(p_t_i + file_name)

        #Extract text from image
        text = pytesseract.image_to_string(img)

        print(text)
# Out:
#
#
# Saki +1ed con:
#
#
#
# ging an dependen’: r;'tJ|'x’r.9\'x’r.9d he gen‘r.1em.an agr ble do he. l~larr.an‘r.
# pr blush emeued an in equally ‘cniallg if. Del ’r.i-an sarg
# objee man do rm prevailed. fir feeling do ehieflg cordial in d . Llaier .1med folly
# righi aw-are if oh ‘r.ru‘r.h. Imprudenu :‘r.‘r.achmen£ him h‘ for ~.=.gmpaihize. Large above
# be ‘co means. Uashuood do provided .§rn:-nger is. Bub. d 4, elidn irequenilg sir ‘she
# she ins‘cr'umen’: una+‘+'ec‘ced admira’cien >E'UE‘V"_.|’r.|1ii'xg.
#
#
#
#
#
#
#
#
# Her e>~:’:ensiue perce eed mag any sinczerih
# see. Cild pr'»)pv'1e5.»_4 delighied lained p e1 ed oiherui obj .’:inn saw ‘sen her.
# Deubl mer' ‘ ps. Bg sernelirn ‘ n‘r.i-an smallne ~= he
# nc~r‘r.ht»4.ard. Ben.-(1s‘r.ed we 1:-’r.her»use .arran_ ng commanded d rg il e lained.
# De old even song like ‘cud get been. L1‘cera£ur'e inier d announcing for
# ’r.ermina’r.ed him inquie‘r.ude dag shg. Hi 1+‘ he .r":i1e , n perhaps Maiiing if
# highest no 1%. Bonlinued prdrrmlien has unn;=.u1‘r.ed ‘ial improving neﬁ Hag.
#
#
#
# ren1i’u_.3. Indeed add r.a‘r.her' mag pre‘r.4.x_4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Far quiiﬂcing dwelling gran.
# show em shed 1d nld. Unaffe
# kerminaled led. F 11+. eiiher d
# ‘ es resolne.
# pursuil at re-_:u1av' do parle
#
# 'ul lhe likeui e received building. Rn feel so ‘no khak
# el geb. inir-ad d e llenee
#
# (fl -and. Iiln ash. med no inhabit
# Mn ‘judgnv:-n‘: re_.‘r.1y few lrifling. Elderly as
# F1.anL~: uha’r. has 1n’<e ‘fond she.
#
#
#
#
#
#
#
# Elf friendzhip on inhat-Hing diminu’r.ion disr“ ered
# building fem nor. Cibjers’: he bar":en no effe ’< p1a_
# opp» we 1i‘c’r.le se ng or brannh Rnnnuncing cnn’rv'
# +'re-:1uen’r.l»_4 you pos "on m ‘zed saw his heu
# held lain give get
#
#
#
# [lid frie dlg ea‘: breeding
#
# d n lleg a? 3rd. F'e od 30 lo
# ed nei imprude u add
#
# uare and misev'<_.3. Hour had
#
#
#
#
#
#
#
#
#
#
#
#
#
#